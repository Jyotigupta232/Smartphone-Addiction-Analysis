# %% [markdown]
# # 🤖 Machine Learning Model Benchmarking & Risk Scoring
# **Target Role Alignment:** XENO AI Native Data Analyst Intern (BTech 2027)
#
# This notebook covers:
# 1. Feature Preprocessing & Scaling.
# 2. Training KNN, Logistic Regression, Decision Tree, and Random Forest models.
# 3. 5-Fold Cross Validation & Weighted F1 Evaluation.
# 4. Feature Importance extraction.

# %%
import sys, os
sys.path.append('..')
from src.ml_engine import train_and_evaluate_models

results, X_scaled, y, feature_cols, scaler = train_and_evaluate_models('../data/smartphone_addiction_dataset.csv')

for model_name, res in results.items():
    print(f"=== {model_name} ===")
    print(f"Accuracy       : {res['accuracy']*100:.2f}%")
    print(f"5-Fold CV Acc  : {res['cv_mean_acc']*100:.2f}%")
    print(f"Weighted F1    : {res['f1_score']:.4f}\n")
